# %% [markdown]
# # Exploratory Data Analysis (EDA)
# This notebook loads raw stock data and performs initial inspection.

# %%
import sys
sys.path.append('.')
import pandas as pd
from config.config import PRIMARY_STOCK, ALL_STOCKS, START_DATE, END_DATE
from src.data_loader import load_single_stock, load_all_stocks
from src.data_cleaner import clean_data

print(f'Primary stock: {PRIMARY_STOCK}')
print(f'Data range: {START_DATE.date()} to {END_DATE.date()}')

# Load single stock
msft = load_single_stock(PRIMARY_STOCK)
print(msft.shape)
msft.head()
# Out:
# Primary stock: MSFT
# Data range: 2025-06-16 to 2026-06-16
# ...
# ✅ Successfully downloaded 252 records for MSFT
# (252, 5)
# Price            Close        High         Low        Open    Volume
# Ticker            MSFT        MSFT        MSFT        MSFT      MSFT
# Date
# 2025-06-16  475.343170  476.880875  471.235962  471.444290  15626100
# 2025-06-17  474.251892  474.946327  470.323250  471.632798  15414100
# 2025-06-18  476.434448  477.188436  470.700252  474.212208  17526500
# 2025-06-20  473.616943  479.628920  473.091144  478.408686  37576200
# 2025-06-23  482.148804  483.884936  468.765712  474.420525  24864000

# %%
# Load all stocks (may take some time)
stocks = load_all_stocks()
print('Loaded:', list(stocks.keys()))
for k, v in stocks.items():
    print(k, v.shape)
# Out:
# ...
# LOADING STOCK DATA
# ...
#
# ...
# ✅ Successfully downloaded 252 records for MSFT
# ...
# ✅ Successfully downloaded 252 records for AAPL
# ...
# ✅ Successfully downloaded 252 records for GOOGL
# ...
# ✅ Successfully downloaded 252 records for NVDA
# ...
# ✅ Successfully downloaded 252 records for TSLA
#
# ✅ Loaded data for 5 stocks
# Loaded: ['MSFT', 'AAPL', 'GOOGL', 'NVDA', 'TSLA']
# MSFT (252, 5)
# AAPL (252, 5)
# GOOGL (252, 5)
# NVDA (252, 5)
# TSLA (252, 5)
